# %% [markdown]
# ## CLASSWORK8 - NAMED ENTITY RECOGNITION
#
# Named Entity Recognition (NER) is a natural language processing (NLP) task that involves identifying and categorizing named entities within a text into predefined categories such as the names of persons, organizations, locations, dates, numerical expressions, and more.

# %% [markdown]
# ## IMPORTING SPACY

# %%
#importing SpaCy
import spacy
# Load the English language model
nlp = spacy.load("en_core_web_lg")

# %% [markdown]
# ## TOKENIZATION AND PRINTING USING SPACY

# %%
# Assign the text to the variable
text = "New kickoff format, ban on hip-drop tackle among 10 rule proposals to be heard at Annual League Meeting"
# Process the title using spaCy
doc = nlp(text)
for token in doc:
    print(token, end="|")
# Out:
# New|kickoff|format|,|ban|on|hip|-|drop|tackle|among|10|rule|proposals|to|be|heard|at|Annual|League|Meeting|

# %% [markdown]
# ## VISUALISATION OF SPACY TOKENS

# %%
#Importing pandas
import pandas as pd

def display_nlp(doc, include_punct=False):
    """Generate data frame for visualization of spaCy tokens."""
    rows = []
    for i, t in enumerate(doc):
        if not t.is_punct or include_punct:
            row = {'token': i,  'text': t.text, 'lemma_': t.lemma_, 
                   'is_stop': t.is_stop, 'is_alpha': t.is_alpha,
                   'pos_': t.pos_, 'dep_': t.dep_, 
                   'ent_type_': t.ent_type_, 'ent_iob_': t.ent_iob_}
            rows.append(row)
    
    df = pd.DataFrame(rows).set_index('token')
    df.index.name = None
    return df
display_nlp(doc)
# Out:
#          text    lemma_  is_stop  is_alpha   pos_      dep_ ent_type_ ent_iob_
# 0         New       new    False      True    ADJ      amod                  O
# 1     kickoff   kickoff    False      True   NOUN  compound                  O
# 2      format    format    False      True   NOUN      ROOT                  O
# 4         ban       ban    False      True   NOUN     appos                  O
# 5          on        on     True      True    ADP      prep                  O
# 6         hip       hip    False      True   NOUN  compound                  O
# 8        drop      drop    False      True   NOUN  compound                  O
# 9      tackle    tackle    False      True   NOUN      pobj                  O
# 10      among     among     True      True    ADP      prep                  O
# 11         10        10    False     False    NUM    nummod  CARDINAL        B
# 12       rule      rule    False      True   NOUN  compound                  O
# 13  proposals  proposal    False      True   NOUN      pobj                  O
# 14         to        to     True      True   PART       aux                  O
# 15         be        be     True      True    AUX   auxpass                  O
# 16      heard      hear    False      True   VERB       acl                  O
# 17         at        at     True      True    ADP      prep                  O
# 18     Annual    Annual    False      True  PROPN  compound     EVENT        B
# 19     League    League    False      True  PROPN  compound     EVENT        I
# 20    Meeting   Meeting    False      True  PROPN      pobj     EVENT        I

# %% [markdown]
# ## FILTERING STOP WORDS AND PUNCTUATIONS

# %%
# initializing text variable
text = "Watch USC QB Caleb Williams' pro day live on NFL+ at 1:30 p.m. ET"
doc = nlp(text)

non_stop = [t for t in doc if not t.is_stop and not t.is_punct]
print(non_stop)
# Out:
# [Watch, USC, QB, Caleb, Williams, pro, day, live, NFL+, 1:30, p.m., ET]

# %% [markdown]
# ## FILTERING NOUNS AND PRONOUNS

# %%
#initializes a text variable 
text = "Arrest warrant issued for Lions CB Cameron Sutton for alleged domestic battery"
doc = nlp(text)
#checkS for having a part-of-speech tag that corresponds to a noun or proper noun
nouns = [t for t in doc if t.pos_ in ['NOUN', 'PROPN']]
print(nouns)
# Out:
# [warrant, Lions, CB, Cameron, Sutton, battery]

# %% [markdown]
# ## NAMED ENTITY RECOGNITION IN TEXT USING SPACY

# %%
#intializes text variable
text = "Mike Williams sees 'great fit' with Aaron Rodgers, Jets: 'A pretty good opportunity ahead of us'"
#processes the text using the spaCy library's language model
doc = nlp(text)

for ent in doc.ents:
    print(f"({ent.text}, {ent.label_})", end=" ")
# Out:
# (Mike Williams, PERSON) (Aaron Rodgers, PERSON) (Jets, ORG)

# %% [markdown]
# ## NAMED ENTITY RECOGNITION

# %%
#initializes a variable
text = "James O'Neill, chairman of World Cargo Inc, lives in San Francisco." 
doc = nlp(text)
#The label represents the type of the named entity
for ent in doc.ents:
    print(f"({ent.text}, {ent.label_})", end=" ")
# Out:
# (James O'Neill, PERSON) (World Cargo Inc, ORG) (San Francisco, GPE)

# %% [markdown]
# ## VISUALIZING NAMED ENTITIES

# %%
#imports the `displacy` module from spaCy to visualize named entities in text
from spacy import displacy
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     James O'Neill
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , chairman of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     World Cargo Inc
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , lives in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     San Francisco
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# .</div></span>

# %% [markdown]
# ## EXTRACTING AND ANALYSING NAMED ENTITIES FROM  WEB ARTICLE

# %%
#pull an article from the web and use it as our data, a reuters new article:
from bs4 import BeautifulSoup
import requests
import re

def url_to_string(url):
    res = requests.get(url)
    html = res.text
    soup = BeautifulSoup(html, 'html.parser')  # Specify 'html.parser' as the parser
    for script in soup(["script", "style", 'aside']):
        script.extract()
    return " ".join(re.split(r'[\n\t]+', soup.get_text()))
#fetches the content of the NFL news article from the specified URL.
ny_bb = url_to_string('https://www.nfl.com/news/')
article = nlp(ny_bb)
len(article.ents)
# Out:
# 154

# %% [markdown]
# ## VISUALIZING NAMED ENTITIES

# %%
#visualization style is set to 'ent'
displacy.render(article, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NFL News |
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Latest NFL Football News | NFL.com       Skip to main content             Open menu button            Primary nav                 Watch NFL+                              RedZone                            NFL Network                            Live Games                            Game Replays                            Shows                            News                              Latest News                            Podcasts                            Injuries                            Transactions                            NFL Writers                            Series                            Scores                            Schedule                              Team Schedules                            TNF
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SNF
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MNF                            Network Games                            Network                            Teams
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#               AFC East
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Buffalo Bills
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Miami Dolphins New England Patriots New York Jets AFC North
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Baltimore
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ravens
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cincinnati
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  Bengals
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cleveland Browns
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pittsburgh
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  Steelers AFC South
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Houston
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Texans
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Indianapolis Colts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jacksonville
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  Jaguars
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tennessee
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  Titans AFC West
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Denver Broncos
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Kansas City Chiefs Los Angeles Chargers
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Las Vegas Raiders
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NFC East
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dallas Cowboys New York Giants Philadelphia Eagles
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Washington Commanders
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NFC North       Chicago Bears
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Detroit Lions Green Bay Packers
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Minnesota
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  Vikings NFC South
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Atlanta Falcons Carolina Panthers New Orleans Saints Tampa Bay Buccaneers
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  NFC West
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Arizona
#     <span style="font-size: 0.8em; font-weigh

# %% [markdown]
# ## COUNTING NAMED ENTITIES LABELS

# %%
#imports the Counter class from the collections
from collections import Counter
#labels of named entities in the web article are extracted and stored 
labels = [x.label_ for x in article.ents]
entity_counter = Counter(labels)
print(entity_counter)
# Out:
# Counter({'ORG': 67, 'GPE': 30, 'PERSON': 12, 'DATE': 12, 'CARDINAL': 8, 'EVENT': 7, 'PRODUCT': 7, 'LOC': 3, 'WORK_OF_ART': 3, 'NORP': 2, 'FAC': 2, 'TIME': 1})

# %% [markdown]
# ## IDENTIFYING ENTITIES USING COUNTER

# %%
# Importing the Counter class from the collections module
items = [x.text for x in article.ents]
Counter(items).most_common(5)
# Out:
# [('NFL', 8), ('Mar 20,', 5), ('2024', 5), ('Houston', 2), ('Texans', 2)]

# %% [markdown]
# ## EXTRACTING AND PRINTING

# %%
# Extracting the sentences from the processed web article using spaCy's sentence
sentences = [x for x in article.sents]
print(sentences[0])
# Out:
#  NFL News |

# %% [markdown]
# ## VISUALIZING NAMED ENTITIES

# %%
# Rendering a visualization of named entities in the first sentence
displacy.render(nlp(str(sentences[0])), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NFL News |
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </div></span>

# %% [markdown]
# ## EXTRACTING TOKEN ATTRIBUTES

# %%
#filters out tokens that are stop words or punctuation marks, then retrieves the specified attributes for each token.
[(x.orth_,x.pos_, x.lemma_) for x in [y 
                                      for y
                                      in nlp(str(sentences[0])) 
                                      if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [(' ', 'SPACE', ' '), ('NFL', 'PROPN', 'NFL'), ('News', 'PROPN', 'News')]

# %% [markdown]
# ## VISUALIZING DEPENDENCY PARSING

# %%
#Rendering a visualization of dependency parsing in the first sentence
displacy.render(nlp(str(sentences[0])), style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="c4f3aaf717944be2be457dc0f50836ba-0" class="displacy" width="530" height="197.0" direction="ltr" style="max-width: none; height: 197.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="107.0">
#     <tspan class="displacy-word" fill="currentColor" x="50"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="107.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">NFL</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="107.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">News</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="107.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">|</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">PUNCT</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c4f3aaf717944be2be457dc0f50836ba-0-0" stroke-width="2px" d="M70,62.0 C70,2.0 170.0,2.0 170.0,62.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c4f3aaf717944be2be457dc0f50836ba-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,64.0 L62,52.0 78,52.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c4f3aaf717944be2be457dc0f50836ba-0-1" stroke-width="2px" d="M190,62.0 C190,2.0 290.0,2.0 290.0,62.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c4f3aaf717944be2be457dc0f50836ba-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M190,64.0 L182,52.0 198,52.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c4f3aaf717944be2be457dc0f50836ba-0-2" stroke-width="2px" d="M310,62.0 C310,2.0 410.0,2.0 410.0,62.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c4f3aaf717944be2be457dc0f50836ba-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M410.0,64.0 L418.0,52.0 402.0,52.0" fill="currentColor"/>
# </g>
# </svg></span>
