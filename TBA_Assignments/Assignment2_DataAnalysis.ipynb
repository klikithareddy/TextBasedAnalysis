# %% [markdown]
# ## CLASSWORK WEEK-2

# %% [markdown]
# ### DATA EXPLORATION AND  REGULAR EXPRESSIONS

# %% [markdown]
#  IMPORTING PACKAGES AND READING FILE

# %%
#This dataset shows information about Cause of deaths of mountainers who climbed K2 mountain
import pandas as pd
file = "deaths.csv"
df = pd.read_csv(file)
df.head(20)  #head() displays first 20 rows
# Out:
#           Date                      Name                  Nationality  \
# 0   2023-07-27           Muhammad Hassan                     Pakistan
# 1   2022-07-22             Matthew Eakin                    Australia
# 2   2022-07-22           Richard Cartier                       Canada
# 3   2022-07-21           Ali Akbar Sakhi                  Afghanistan
# 4   2021-07-25                Rick Allen               United Kingdom
# 5   2021-02-05               Ali Sadpara                     Pakistan
# 6   2021-02-05    Juan Pablo Mohr Prieto                        Chile
# 7   2021-02-05  John Snorri Sigurjónsson                      Iceland
# 8   2021-02-05             Atanas Skatov                     Bulgaria
# 9   2021-01-16             Sergi Mingote                        Spain
# 10  2018-07-22           Watanabe Kojiro                        Japan
# 11  2018-07-07         Serge Dessureault                       Canada
# 12  2014-07-30        Miguel Ángel Pérez                        Spain
# 13  2013-07-27             Marty Schmidt  New Zealand / United States
# 14  2013-07-27            Denali Schmidt  New Zealand / United States
# 15  2012-02-06           Vitaliy Gorelik                       Russia
# 16  2010-08-06          Fredrik Ericsson                       Sweden
# 17  2010-07-17    Petar Georgiev Unzhiev                     Bulgaria
# 18  2009-06-23              Michele Fait                        Italy
# 19  2008-08-02            Hwang Dong-jin                  South Korea
#
#                                       Cause of death Mountain
# 0                                            Unknown       K2
# 1                                               Fall       K2
# 2                                               Fall       K2
# 3               Unknown, suspected altitude sickness       K2
# 4                                          Avalanche       K2
# 5   Froze to death in storm, remains found July 2021       K2
# 6   Froze to death in storm, remains found July 2021       K2
# 7   Froze to death in storm, remains found July 2021       K2
# 8                    Fall during descent from Camp 3       K2
# 9                    Fall during descent from Camp 1       K2
# 10                               Fall during descent       K2
# 11                                              Fall       K2
# 12                 Unclear, likely altitude sickness       K2
# 13                                         Avalanche       K2
# 14                                         Avalanche       K2
# 15                                         Frostbite       K2
# 16                          Fall from the Bottleneck       K2
# 17                                 Altitude sickness       K2
# 18                                    Fall with skis       K2
# 19                                 Fourth serac fall       K2

# %% [markdown]
# ### DISPLAYING COLUMNS IN DATAFRAME

# %%
#displays all the columns in the dataframe
df.columns
# Out:
# Index(['Date', 'Name', 'Nationality', 'Cause of death', 'Mountain'], dtype='object')

# %% [markdown]
# ### DATA TYPES OF EACH COLUMN

# %%
#gives datatype of columns
df.dtypes
# Out:
# Date              object
# Name              object
# Nationality       object
# Cause of death    object
# Mountain          object
# dtype: object

# %% [markdown]
# ## INFO METHOD

# %%
# gives information about all the columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1078 entries, 0 to 1077
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            1078 non-null   object
#  1   Name            1078 non-null   object
#  2   Nationality     1076 non-null   object
#  3   Cause of death  1069 non-null   object
#  4   Mountain        1078 non-null   object
# dtypes: object(5)
# memory usage: 42.2+ KB

# %% [markdown]
# ## DESCRIPTIVE STATISTICS

# %%
df.describe()  #generates descriptive statistics of DataFrame
# Out:
#               Date          Name Nationality Cause of death       Mountain
# count         1078          1078        1076           1069           1078
# unique         676          1053          73            181             14
# top     2015-04-25  Ang Tshering       Nepal      Avalanche  Mount Everest
# freq            17             3         240            276            331

# %% [markdown]
# ### LENGTH FUNCTION

# %%
df['length'] = df['Name'].str.len()  #creates new column length that has length of name
df.describe()
# Out:
#             length
# count  1078.000000
# mean     14.706865
# std       4.616527
# min       4.000000
# 25%      12.000000
# 50%      14.000000
# 75%      17.000000
# max      38.000000

# %% [markdown]
# ## DESCRIBE METHOD

# %%
#gives descriptive statistics
df.describe(include='O')
# Out:
#               Date          Name Nationality Cause of death       Mountain
# count         1078          1078        1076           1069           1078
# unique         676          1053          73            181             14
# top     2015-04-25  Ang Tshering       Nepal      Avalanche  Mount Everest
# freq            17             3         240            276            331

# %% [markdown]
# ## CHECKING FOR NULL VALUES

# %%
#isna() checks for null values and sum() adds total missing values 
df['Nationality'].fillna('unknown', inplace=True)
df['Cause of death'].fillna('unknown', inplace=True)
df.isna().sum()
# Out:
# Date              0
# Name              0
# Nationality       0
# Cause of death    0
# Mountain          0
# length            0
# dtype: int64

# %% [markdown]
# ## CONVERTING TO UPPERCASE WITH KEYWORD

# %%
df['Nationality'] = df['Nationality'].str.upper()
df['Cause of death'] = df['Cause of death'].str.upper() #converts position column to uppercase
df['Name'] = df['Name'].str.upper()

# %% [markdown]
# ### COLUMN BY NAMES

# %% [markdown]
# ### PLOTTING

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## .2 LINEPLOT

# %%
# .2 line plot for length column
df['length'].plot(kind = 'line',color = 'lavender')
plt.xlabel('Length')
plt.ylabel('Length')
plt.title('Line plot')
# Out:
# Text(0.5, 1.0, 'Line plot')

# %% [markdown]
# ### BOXPLOT

# %%
# Boxplot for length column
df['length'].plot(kind='box', vert=False)
plt.xlabel('Length')
plt.title('BOXPLOT')
# Out:
# Text(0.5, 1.0, 'BOXPLOT')

# %% [markdown]
# ### HISTOGRAM

# %%
# Histogram for 30 samples for length coulmn

df['length'].plot(kind='hist', bins=30)
plt.xlabel('Length')
plt.ylabel('Frequency')
plt.title('Histogram for length')
plt.legend()
plt.show()

# %% [markdown]
# ### BOXPLOT

# %% [markdown]
# seaborn is used for making statistcal graphics in python

# %%
# Boxplot for 5 samples in Country column
import seaborn as sns 
where = df['Nationality'].isin(['AUSTRALIA', 'CANADA', 'JAPAN', 'ITALY', 'SWEDEN'])
g = sns.catplot(data=df[where], x="Nationality", y="length", kind='box')
g.fig.set_size_inches(10, 8) ###
# Out:
# /Users/likithareddykotla/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## AREA PLOT

# %%
#Area plot for length column
df['length'].plot(kind='area',color = 'red')
# Out:
# <Axes: >

# %% [markdown]
# ### REGULAR EXPRESSIONS

# %% [markdown]
# REGEX :Regular expression (regex or regexp) is a sequence of characters that forms a search pattern.
#     It is a powerful tool for string manipulation and searching.
#     The re module in Python provides support for regular expressions.

# %%
# importing regex package
import regex as re

def tokenize(text):
    return re.findall(r'[\w-]*[a-z|A-Z][\w-]*', text)

# %% [markdown]
# ## TOKENIZATION

# %%
testtext = "Hi welcome to TEXT BASED ANALYSIS class welcome to you all"
testtokens = tokenize(testtext)
 
print(testtokens)
# Out:
# ['Hi', 'welcome', 'to', 'TEXT', 'BASED', 'ANALYSIS', 'class', 'welcome', 'to', 'you', 'all']

# %% [markdown]
# ### STOPWORDS

# %% [markdown]
# In natural language processing, stopwords are commonly used words (such as "the," "is," "and," etc.) that are often excluded from text processing because they do not carry significant meaning and are used for grammatical structure. In Python, the nltk (Natural Language Toolkit) library is commonly used for working with text data, including handling stopwords.

# %%
#importing nltk package
import nltk 
nltk.download('stopwords')
stopwords = set(nltk.corpus.stopwords.words('english'))
print(stopwords)
# Out:
# {'any', 'hers', 'been', 'now', "wasn't", 'few', 'again', 'each', 'shan', 'don', 'no', 'himself', 'haven', "haven't", 'she', 'all', "doesn't", "you've", 'theirs', 'he', "you're", 'are', 'over', 'can', "mightn't", 'some', 'ours', 'should', 's', 'there', 'themselves', 'yours', 'and', 'between', 'll', 'myself', 'at', 'yourself', 'me', 'will', 'off', 'from', 'for', 'won', 'after', "don't", 'doing', 'o', 'this', 'during', 'isn', 'mightn', 'very', 'its', 'my', 'of', 'when', 'they', 'wouldn', 'aren', 'you', 'so', 'itself', 'to', 'y', 'not', 'was', 'whom', 'have', 'ma', 'into', 'only', 'above', "it's", 'until', 'the', 'their', "didn't", 'then', 'own', 'just', "should've", 'once', 'in', 're', 'what', "weren't", 'these', 'but', 'herself', 'an', "wouldn't", 'needn', 'because', 'it', 'how', 'who', 'most', 'if', 't', 'does', 'a', 'through', 'your', 'them', 'as', 'i', "that'll", 'where', "mustn't", 'further', 'her', 'against', "aren't", 'do', 'didn', "shan't", 'him', "you'll", 'down', 'd', 'we', "you'd", 'mustn', 'ain', 'be', 'has', "isn't", 'here', 'with', 'below', 'his', 'yourselves', 'being', "shouldn't", 'did', 'under', 'too', 'shouldn', "needn't", 'other', 'couldn', "hadn't", 'before', 'more', 'about', 'had', "won't", 'our', 'up', 'same', 'weren', "she's", 'doesn', "hasn't", 'wasn', 'those', 'out', 'both', 'on', 'such', 'nor', 'that', 'is', 'm', 've', 'which', 'or', 'hadn', 'hasn', 'having', 'while', "couldn't", 'were', 'ourselves', 'why', 'am', 'than', 'by'}
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/likithareddykotla/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## TOKENIZATION

# %%
# Removing stopwords from given string
def remove_stop(tokens):
    return [t for t in tokens if t.lower() not in stopwords]
#testing it
cleantokens= remove_stop(testtokens)
print(cleantokens)
# Out:
# ['Hi', 'welcome', 'TEXT', 'BASED', 'ANALYSIS', 'class', 'welcome']

# %% [markdown]
# ## TEXT PROCESSING PIPELINE

# %%
#Lowercasing, Tokenization, and Stopword Removal

pipeline = [str.lower, tokenize, remove_stop]

def prepare(text, pipeline):
    tokens = text
    for fun in pipeline:
        tokens = fun(tokens)
    return tokens

# %% [markdown]
# ### TEXT PROCESSING PIPELINE

# %%
#Applying a custom text processing pipeline to the 'text' column in the DataFrame
df['tokens'] = df['Cause of death'].apply(prepare, pipeline=pipeline)

# %% [markdown]
# ### CALCULATING TOKENS IN EACH ENTRY

# %% [markdown]
# ### Calculating Number of Tokens in Each Text Entry and Adding a 'num_tokens' Column to the DataFrame
# df['num_tokens'] = df['tokens'].map(len)
# df.tail()  # tail() function gives last 5 rows in a dataframe

# %% [markdown]
# ### COUNTING WORDS

# %% [markdown]
# A Counter is a data type in the collections module. It is a dict subclass that stores counts for hashable objects.

# %%
from collections import Counter

tokens = tokenize("kids like to eat chocolates and they don't want to share their chocolates")

testcount= Counter(tokens)   #counts each word and its occurence
print(testcount)
# Out:
# Counter({'to': 2, 'chocolates': 2, 'kids': 1, 'like': 1, 'eat': 1, 'and': 1, 'they': 1, 'don': 1, 't': 1, 'want': 1, 'share': 1, 'their': 1})

# %% [markdown]
# ### DISPLAYING KEY VALUES

# %%
counter = Counter()
df['tokens'].map(counter.update)  #iterates over each entry,updating the counter with the token counts
print(counter.most_common(5))
# Out:
# [('avalanche', 326), ('fall', 289), ('altitude', 82), ('sickness', 81), ('unknown', 79)]

# %% [markdown]
# ### CREATING DATAFRAME AND FILTERING ENTRIES

# %%
freq_df = pd.DataFrame.from_dict(counter, orient='index', columns=['freq'])
freq_df = freq_df.query('freq >= 1') #include only rows where the 'freq' column is greater than or equal to 1.
freq_df.index.name = 'token'

# %% [markdown]
# ### SORTING

# %%
#Sorts and displays
freq_df = freq_df.sort_values('freq', ascending=False) 
freq_df.head(10)
# Out:
#              freq
# token
# avalanche     326
# fall          289
# altitude       82
# sickness       81
# unknown        79
# disappeared    64
# exposure       54
# exhaustion     53
# camp           45
# base           33

# %% [markdown]
# ### DESCRIPTIVE STATISTICS

# %%
freq_df.describe() #describe() can give you information such as the count, mean, standard deviation...
# Out:
#              freq
# count  209.000000
# mean     9.430622
# std     32.138765
# min      1.000000
# 25%      1.000000
# 50%      2.000000
# 75%      5.000000
# max    326.000000

# %% [markdown]
# ### BARPLOT

# %% [markdown]
# Bar plots are commonly used to show the distribution of a categorical variable or to compare the values of different categories.

# %%
ax = freq_df.head(15).plot(kind='barh', width=0.95, figsize=(12,8))
ax.invert_yaxis()   #Inverts the y-axis, so the highest frequency is at the top of the plot.
ax.set(xlabel='Frequency', ylabel='Token', title='Top Words')
# Out:
# [Text(0.5, 0, 'Frequency'), Text(0, 0.5, 'Token'), Text(0.5, 1.0, 'Top Words')]

# %% [markdown]
# ## WORDCLOUD

# %% [markdown]
# Word cloud is one of the most powerful and straightforward visualization methods
# when it comes to text data. The size of words are dependent on the occurrence frequency

# %%
#importing wordcloud 
from wordcloud import WordCloud
from matplotlib import pyplot as plt
wc = WordCloud(background_color='black', width = 600, height=600, max_words=100, margin=2)

text = df.query("Name==ATANAS SKAT" and "Nationality=='CHILE'")['Cause of death'].values[0]

plt.figure(figsize=(14, 10)) ###

wc.generate(text)   # Generates the WordCloud from the input text data.
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 599.5, 599.5, -0.5)

# %% [markdown]
# ### Example 2 : Word Cloud Visualization of Token Frequencies

# %%
wc = WordCloud(background_color='white', width = 800, height=800, max_words=100, margin=2)
wc.fit_words(freq_df['freq'].to_dict() ) # uses the frequency information from the DataFrame to fit the WordCloud.
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wc) #displays the WordCloud.
plt.axis("off")
plt.tight_layout(pad = 0)
plt.show()
