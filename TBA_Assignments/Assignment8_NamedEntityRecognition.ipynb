# %% [markdown]
# ## ASSIGNMENT 9 - NAMED ENTITY RECOGNITION

# %% [markdown]
# Spacy is a powerful natural language processing (NLP) library in Python, known for its speed and efficiency in handling large volumes of text data. It offers robust features for tokenization, part-of-speech tagging, named entity recognition, and dependency parsing, making it a popular choice for NLP tasks.

# %% [markdown]
# ## LOADING SPACY MODELS FOR ENGLISH AND FRENCH

# %%
# Load Spacy models for processing text in Chinese and English.

import spacy
nlp = spacy.load("zh_core_web_lg")
nlp = spacy.load("en_core_web_lg")

# %% [markdown]
# ### TOKENIZE TEXT

# %%
# Tokenize the given text and print each token along with its attributes.

text = "NER could recognize the term Netflix in a document and classify it as a company"
doc = nlp(text)
for token in doc:
    print(token, end=" | ")
# Out:
# NER | could | recognize | the | term | Netflix | in | a | document | and | classify | it | as | a | company |

# %% [markdown]
# ### GENERATE DATAFRAME FOR TOKEN VISUALIZATION

# %%
# Generate a dataframe for visualizing spaCy tokens with options to include or exclude punctuation.

import pandas as pd

def display_nlp(doc, include_punct=False):
    #Generate data frame for visualization of spaCy tokens.
    rows = []
    for i, t in enumerate(doc):
        if not t.is_punct or include_punct:
            row = {'token': i,  'text': t.text, 'lemma_': t.lemma_, 
                   'is_stop': t.is_stop, 'is_alpha': t.is_alpha,
                   'pos_': t.pos_, 'dep_': t.dep_, 
                   'ent_type_': t.ent_type_, 'ent_iob_': t.ent_iob_}
            rows.append(row)
    
    df = pd.DataFrame(rows).set_index('token')
    df.index.name = None
    return df
display_nlp(doc)
# Out:
#          text     lemma_  is_stop  is_alpha   pos_   dep_ ent_type_ ent_iob_
# 0         NER        NER    False      True  PROPN  nsubj       ORG        B
# 1       could      could     True      True    AUX    aux                  O
# 2   recognize  recognize    False      True   VERB   ROOT                  O
# 3         the        the     True      True    DET    det                  O
# 4        term       term    False      True   NOUN   dobj                  O
# 5     Netflix    Netflix    False      True  PROPN  appos       ORG        B
# 6          in         in     True      True    ADP   prep                  O
# 7           a          a     True      True    DET    det                  O
# 8    document   document    False      True   NOUN   pobj                  O
# 9         and        and     True      True  CCONJ     cc                  O
# 10   classify   classify    False      True   VERB   conj                  O
# 11         it         it     True      True   PRON   dobj                  O
# 12         as         as     True      True    ADP   prep                  O
# 13          a          a     True      True    DET    det                  O
# 14    company    company    False      True   NOUN   pobj                  O

# %% [markdown]
# ### FILTER OUT STOP WORDS AND PUNCTUATION

# %% [markdown]
# Stopwords are common words like "and," "the," and "is" that are often filtered out during text analysis to focus on meaningful content. Punctuation marks, such as commas, periods, and exclamation points, are symbols used to organize and convey meaning in written language, often removed or processed separately in text processing tasks.

# %%
# Extract non-stop words and non-punctuation tokens from the given text.

text = "NER utilizes natural language processing (NLP) to tag entities based on predefined parameters"
doc = nlp(text)

non_stop = [t for t in doc if not t.is_stop and not t.is_punct]
print(non_stop)
# Out:
# [NER, utilizes, natural, language, processing, NLP, tag, entities, based, predefined, parameters]

# %% [markdown]
# ### EXTRACT NOUNS FROM TEXT

# %%
# Extract nouns and proper nouns from the given text.

text = "NER utilizes natural language processing (NLP) to tag entities based on predefined parameters"
doc = nlp(text)

nouns = [t for t in doc if t.pos_ in ['NOUN', 'PROPN']]
print(nouns)
# Out:
# [NER, language, processing, NLP, entities, parameters]

# %% [markdown]
# ### IDENTIFY ENTITIES IN TEXT

# %%
# Print identified entities along with their labels.

text = "NER could recognize the term Netflix in a document and classify it as a company"
doc = nlp(text)

for ent in doc.ents:
    print(f"({ent.text}, {ent.label_})", end=" ")
# Out:
# (NER, ORG) (Netflix, ORG)

# %% [markdown]
# ### IDENTIFY ENTITIES IN TEXT

# %% [markdown]
# Identifying entities in text involves recognizing and categorizing specific pieces of information such as names of people, organizations, locations, dates, and numerical expressions. This process often utilizes techniques like named entity recognition (NER) to automatically extract and classify these entities within a given text corpus, enabling deeper semantic analysis and information retrieval.

# %%
# Print identified entities along with their labels.

text = "NER can be applied to invoices to automate the identification of account IDs, shipping and billing addresses, and invoice amounts." 
doc = nlp(text)

for ent in doc.ents:
    print(f"({ent.text}, {ent.label_})", end=" ")
# Out:
# (NER, ORG)

# %% [markdown]
# ### VISUALIZE ENTITIES IN TEXT

# %%
# Render a visualization of the identified entities in the text.

from spacy import displacy

displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NER
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  can be applied to invoices to automate the identification of account IDs, shipping and billing addresses, and invoice amounts.</div></span>

# %% [markdown]
# ## 1. CONVERT URL TO TEXT AND COUNT ENTITIES

# %%
# Convert the content of a given URL into text and count the identified entities.

from bs4 import BeautifulSoup
import requests
import re
def url_to_string(url):
    res = requests.get(url)
    html = res.text
    soup = BeautifulSoup(html, 'html.parser')
    for script in soup(["script", "style", 'aside']):
        script.extract()
    return " ".join(re.split(r'[\n\t]+', soup.get_text()))
ny_bb = url_to_string('https://www.mingpao.com')
article = nlp(ny_bb)
len(article.ents)
# Out:
# 87

# %% [markdown]
# ### VISUALIZE ENTITIES IN TEXT

# %%
# Render a visualization of the identified entities in the extracted article text.

displacy.render(article, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"> 明報網站 | 明報
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2024年03月25日星期一
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     熱門搜尋
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# :
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     香港怎麼辦系列 日月掠影 麥明詩婚禮 鼻敏感藥 彩色渠蓋 特色配電箱 【
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     圖輯】維港兩岸各有活動　復活節帽子巡遊北角至灣仔海濱舉行　尖沙嘴海旁辦基層墟市
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     新股遞表半年內上市比例跌至12
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# %
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     平均447日才掛牌 分析：受市况弱內地備案制影響
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  教大視藝教育碩士課程重實踐
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     培育新一代 各行各業融入藝術之美發揮創造力 《
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# 中年2》決賽｜楊千嬅捲是非拒受訪 伍仲衡反擊周啟生 下午茶之選｜Tomacado花廚 x Rituals「如淋春櫻」雙人限定下午茶 訂閱潛逃者屬財援否 「明知」是關鍵 林定國：針對潛逃者非針對自由
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     23條刊憲生效
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     今日明報 即時新聞     訂閱潛逃者屬財援否 「
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# 明知」是關鍵 林定國：針對潛逃者非針對自由 23條刊憲生效      納米塗層針＋光學技術 3分鐘可測食安
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     新股遞表半年內上市比例跌至12
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
# %
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     平均447日才掛牌 分析：受市况弱內地備案制影響
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# 賀澳門酒店開幕 賭王家族成員齊現身 趙露思人氣勁 玉澤演狂擺甫士搶鏡      人多活少薪降 馬駒橋黎明前覓希望 京郊散工求職點 競爭趨大「錢不好掙
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     」      莫斯科恐襲ISIS認責
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  俄矛頭指烏克蘭 槍手音樂廳掃射縱火133死 20年最血腥   更多...      《中年2》決賽｜楊千嬅捲是非拒受訪 伍仲衡反擊周啟生      陳慧琳國語新歌《謝謝你陪我那麼久》帶出失去才懂珍惜
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     大埔私家車與電單車相撞
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# 　鐵騎受傷送院      錯播國歌｜鐵人賽英國選手奪冠
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     香港賽會播西班牙國歌
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# 足球︱利華小將華迪斯締德國隊史最快入球　領銜友賽作客兩球贈法國      《
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     中年2》決賽｜古淖文99分奪冠喜極而泣 譚輝智顏米羔膺亞季軍
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#    更多...  明報影片       唐英年﹕藝文巨擘聚港振經濟 冀創職位助青年追夢      俄音樂會恐襲增至143死　11人被捕包括4名直接參與者【短片】      【遊走大灣區】巨無霸「壹方天地」 你想的都有！      勁甜麥婚宴｜麥明詩最愛「5年抱8」祝福 盛勁為趁假期日日進補      JUMP招聘及進修日2023：精彩重溫（附短片）      英王查理斯三世聖誕文告
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     英語全文  財經
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     新股遞表半年內上市比例跌至12
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# %
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     平均447日才掛牌 分析：受市况弱內地備案制影響 3月新盤成交破3600宗
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     新例後紀錄
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#   共吸金逾360億  恒地料涉67億佔最多 即時財經 近百企向中證監 申備案惟尚未獲登記 平保：去年撥備充足 今年可避免 中石化去年少賺9.9% 末期息0.2元 幣護冀年底前為逾10港銀提供服務 富蘭克林鄧普頓Ed Perks：美料減息1.5厘  利好美股債
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     提醒Nvidia微軟存投資風險
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  瑞銀：日本走出通縮  股市升浪料未完 維昇連年虧損
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     開發治「侏儒症」藥
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  更多... 專欄 社評 社評：王毅訪澳紐開新篇
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     太平洋依然難太平 呂大樂
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  筆陣：新形勢底下
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     香港有沒有新議程  ／文：呂大樂
#     <span

# %% [markdown]
# ### COUNT ENTITY LABELS

# %%
# Count the occurrence of each entity label in the extracted article text.

from collections import Counter

labels = [x.label_ for x in article.ents]
Counter(labels)
# Out:
# Counter({'ORG': 26,
#          'PERSON': 12,
#          'CARDINAL': 4,
#          'GPE': 4,
#          'QUANTITY': 1,
#          'EVENT': 1,
#          'TIME': 1,
#          'PRODUCT': 1})

# %% [markdown]
# ### COUNT MOST COMMON ENTITIES

# %%
# Count the most common entities in the extracted article text.

items = [x.text for x in article.ents]
Counter(items).most_common(5)
# Out:
# [('新股遞表半年內上市比例跌至12', 3),
#  ('2024年03月25日星期一 \u3000\u3000\u3000 ', 1),
#  ('熱門搜尋', 1),
#  ('香港怎麼辦系列 日月掠影 麥明詩婚禮 鼻敏感藥 彩色渠蓋 特色配電箱 【', 1),
#  ('圖輯】維港兩岸各有活動\u3000復活節帽子巡遊北角至灣仔海濱舉行\u3000尖沙嘴海旁辦基層墟市', 1)]

# %% [markdown]
# ### PRINT SPECIFIC SENTENCE

# %%
# Print the 21st sentence from the extracted article text.

sentences = [x for x in article.sents]
print(sentences[20])
# Out:
# TopGear Lotus Eletre電動蓮花 MingWatch HK 東方表行銅鑼灣Fashion Walk全新形象店開幕 全球國際品牌正式登陸新店

# %% [markdown]
# ### VISUALIZE ENTITIES IN SPECIFIC SENTENCE

# %%
# Render a visualization of the identified entities in the 21st sentence of the extracted article text.

displacy.render(nlp(str(sentences[20])), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TopGear
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lotus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Eletre電動蓮花 MingWatch HK 東方表行銅鑼灣Fashion Walk全新形象店開幕
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  全球國際品牌正式登陸新店</div></span>

# %% [markdown]
# ### EXTRACT WORDS WITH PARTS OF SPEECH AND LEMMAS

# %%
# Extract words along with their parts of speech and lemmas from the 21st sentence of the extracted article text, excluding stop words and punctuation.

[(x.orth_,x.pos_, x.lemma_) for x in [y 
                                      for y
                                      in nlp(str(sentences[20])) 
                                      if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [('TopGear', 'PROPN', 'TopGear'),
#  ('Lotus', 'PROPN', 'Lotus'),
#  ('Eletre電動蓮花', 'PROPN', 'Eletre電動蓮花'),
#  ('MingWatch', 'PROPN', 'MingWatch'),
#  ('HK', 'PROPN', 'HK'),
#  ('東方表行銅鑼灣Fashion', 'NUM', '東方表行銅鑼灣fashion'),
#  ('Walk全新形象店開幕', 'PROPN', 'Walk全新形象店開幕'),
#  ('全球國際品牌正式登陸新店', 'NOUN', '全球國際品牌正式登陸新店')]

# %% [markdown]
# ### VISUALIZE DEPENDENCY PARSING

# %% [markdown]
# Dependency parsing is a technique in natural language processing (NLP) that analyzes the grammatical structure of a sentence by determining the relationships between words, represented as directed edges between tokens in a dependency tree. It helps uncover the syntactic dependencies and hierarchical structure within sentences, facilitating tasks like semantic analysis, question answering, and machine translation.

# %%
# Render a visualization of the dependency parsing for the 21st sentence of the extracted article text with adjusted distance between words.

displacy.render(nlp(str(sentences[20])), style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="fac711986b684d4cac560257e55a2837-0" class="displacy" width="1010" height="317.0" direction="ltr" style="max-width: none; height: 317.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">TopGear</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">Lotus</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">Eletre電動蓮花</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">MingWatch</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">HK</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">東方表行銅鑼灣Fashion</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">Walk全新形象店開幕</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">全球國際品牌正式登陸新店</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fac711986b684d4cac560257e55a2837-0-0" stroke-width="2px" d="M70,182.0 C70,122.0 160.0,122.0 160.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fac711986b684d4cac560257e55a2837-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,184.0 L62,172.0 78,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fac711986b684d4cac560257e55a2837-0-1" stroke-width="2px" d="M190,182.0 C190,122.0 280.0,122.0 280.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fac711986b684d4cac560257e55a2837-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M190,184.0 L182,172.0 198,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fac711986b684d4cac560257e55a2837-0-2" stroke-width="2px" d="M310,182.0 C310,2.0 890.0,2.0 890.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fac711986b684d4cac560257e55a2837-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M310,184.0 L302,172.0 318,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fac711986b684d4cac560257e55a2837-0-3" stroke-width="2px" d="M430,182.0 C430,122.0 520.0,122.0 520.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fac711986b684d4cac560257e55a2837-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M430,184.0 L422,172.0 438,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fac711986b684d4cac560257e55a2837-0-4" stroke-width="2px" d="M550,182.0 C550,122.0 640.0,122.0 640.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fac711986b684d4cac560257e55a2837-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M550,184.0 L542,172.0 558,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fac711986b684d4cac560257e55a2837-0-5" stroke-width="2px" d="M310,182.0 C310,62.0 645.0,62.0 645.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fac711986b684d4cac560257e55a2837-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">appos</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M645.0,184.0 L653.0,172.0 637.0,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fac711986b684d4cac560257e55a2837-0-6" stroke-width="2px" d="M790,182.0 C790,122.0 880.0,122.0 880.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fac711986b684d4cac560257e55a2837-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M790,184.0 L782,172.0 798,172.0" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# ## 2 CONVERT URL TO TEXT AND COUNT ENTITIES

# %%
# Convert the content of a given URL into text and count the identified entities

from bs4 import BeautifulSoup
import requests
import re
def url_to_string(url):
    res = requests.get(url)
    html = res.text
    soup = BeautifulSoup(html, 'html.parser')
    for script in soup(["script", "style", 'aside']):
        script.extract()
    return " ".join(re.split(r'[\n\t]+', soup.get_text()))
ny_bb = url_to_string('https://apnews.com/article/israel-hamas-war-news-03-24-2024-24019f74683075740bf4dd8f7a42dfd8')
article = nlp(ny_bb)
len(article.ents)
# Out:
# 244

# %% [markdown]
# ### VISUALIZE ENTITIES IN TEXT

# %%
# Render a visualization of the identified entities in the extracted article text.

displacy.render(article, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Israel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# -Hamas war:
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Palestinians
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  describe raid around
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gaza
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  hospital | AP News Menu Menu World U.S. Election 2024 Politics Sports Entertainment Business Science Fact Check Oddities Newsletters Video Health Photography  Climate Personal Finance Tech Lifestyle Religion AP Buyline Personal Finance Press Releases ... World Israel-Hamas War
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# -Ukraine War      Global elections
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Asia Pacific
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Latin America
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Europe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Africa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Middle East
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     China
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Australia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S. Election 2024
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#  Politics
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Joe Biden
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Election 2024
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Congress      Sports March Madness
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
# MLB
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NBA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#       NHL      NFL      Soccer      Golf      Tennis      AP Top 25 Poll      Entertainment Movie reviews      Book reviews      Celebrity      Television      Music      Business Inflation      Personal finance      Financial Markets      Business Highlights      Financial wellness
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Science Fact Check Oddities Newsletters Video Health Photography  Climate Personal Finance Tech Artificial Intelligence      Social Media      Lifestyle Religion AP Buyline Personal Finance Press Releases                   Search Query                Submit Search             Show Search
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     World Israel-Hamas War
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# -Ukraine War      Global elections
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Asia Pacific
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Latin America
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Europe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1;

# %% [markdown]
# ### COUNT ENTITY LABELS

# %%
# Count the occurrence of each entity label in the extracted article text.

from collections import Counter

labels = [x.label_ for x in article.ents]
Counter(labels)
# Out:
# Counter({'GPE': 65,
#          'ORG': 46,
#          'DATE': 32,
#          'NORP': 30,
#          'CARDINAL': 23,
#          'PERSON': 19,
#          'LOC': 10,
#          'WORK_OF_ART': 8,
#          'EVENT': 5,
#          'LAW': 2,
#          'QUANTITY': 2,
#          'PERCENT': 1,
#          'TIME': 1})

# %% [markdown]
# ### COUNT MOST COMMON ENTITIES

# %%
# Count the 25 most common entities in the extracted article text.

items = [x.text for x in article.ents]
Counter(items).most_common(25)
# Out:
# [('Gaza', 18),
#  ('Israeli', 14),
#  ('Israel', 12),
#  ('Hamas', 9),
#  ('AP', 8),
#  ('Palestinians', 7),
#  ('The Associated Press', 5),
#  ('Rafah', 4),
#  ('Sunday', 4),
#  ('Shifa', 4),
#  ('Russia', 3),
#  ('China', 3),
#  ('Gaza Strip', 3),
#  ('Shifa Hospital', 3),
#  ('November', 3),
#  ('Hezbollah', 3),
#  ('Asia Pacific', 2),
#  ('Latin America      ', 2),
#  ('Europe', 2),
#  ('Africa', 2),
#  ('Middle East', 2),
#  ('Australia', 2),
#  ('U.S. Election 2024', 2),
#  ('Joe Biden', 2),
#  ('Election 2024', 2)]

# %% [markdown]
# ### PRINT SPECIFIC SENTENCE

# %%
# Print the 4th sentence from the extracted article text.

sentences = [x for x in article.sents]
print(sentences[3])
# Out:
# Top 25 Poll      Entertainment Movie reviews      Book reviews      Celebrity      Television      Music      Business Inflation      Personal finance      Financial Markets      Business Highlights      Financial wellness      Science Fact Check Oddities Newsletters Video Health Photography  Climate Personal Finance Tech Artificial Intelligence      Social Media      Lifestyle Religion AP Buyline Personal Finance Press Releases                   Search Query                Submit Search             Show Search          World Israel-Hamas War      Russia-Ukraine War      Global elections      Asia Pacific      Latin America      Europe      Africa      Middle East      China      Australia      U.S. Election 2024 Politics Joe Biden      Election 2024      Congress      Sports March Madness      MLB      NBA      NHL      NFL      Soccer      Golf      Tennis      AP

# %% [markdown]
# ### VISUALIZE ENTITIES IN SPECIFIC SENTENCE

# %%
# Render a visualization of the identified entities in the 4th sentence of the extracted article text.

displacy.render(nlp(str(sentences[3])), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Top 25 Poll      Entertainment Movie reviews      Book reviews      Celebrity      Television      Music      Business Inflation      Personal finance      Financial Markets      Business Highlights      Financial wellness
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Science Fact Check Oddities Newsletters Video Health Photography  Climate Personal Finance Tech Artificial Intelligence      Social Media      Lifestyle Religion AP Buyline Personal Finance Press Releases                   Search Query                Submit Search             Show Search
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     World Israel-Hamas War
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# -Ukraine War      Global elections
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Asia Pacific
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Latin America
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Europe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Africa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Middle East
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     China
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Australia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S. Election 2024
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#  Politics
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Joe Biden
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Election 2024
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Congress      Sports March Madness
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
# MLB
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NBA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#       NHL      NFL      Soccer      Golf      Tennis      AP</div></span>

# %% [markdown]
# ### EXTRACT WORDS WITH PARTS OF SPEECH AND LEMMAS

# %%
# Extract words along with their parts of speech and lemmas from the 4th sentence of the extracted article text, excluding stop words and punctuation.

[(x.orth_,x.pos_, x.lemma_) for x in [y 
                                      for y
                                      in nlp(str(sentences[3])) 
                                      if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [('25', 'NUM', '25'),
#  ('Poll', 'PROPN', 'Poll'),
#  ('     ', 'SPACE', '     '),
#  ('Entertainment', 'PROPN', 'Entertainment'),
#  ('Movie', 'PROPN', 'Movie'),
#  ('reviews', 'VERB', 'review'),
#  ('     ', 'SPACE', '     '),
#  ('Book', 'PROPN', 'Book'),
#  ('reviews', 'NOUN', 'review'),
#  ('     ', 'SPACE', '     '),
#  ('Celebrity', 'PROPN', 'Celebrity'),
#  ('     ', 'SPACE', '     '),
#  ('Television', 'PROPN', 'Television'),
#  ('     ', 'SPACE', '     '),
#  ('Music', 'PROPN', 'Music'),
#  ('     ', 'SPACE', '     '),
#  ('Business', 'PROPN', 'Business'),
#  ('Inflation', 'PROPN', 'Inflation'),
#  ('     ', 'SPACE', '     '),
#  ('Personal', 'ADJ', 'personal'),
#  ('finance', 'NOUN', 'finance'),
#  ('     ', 'SPACE', '     '),
#  ('Financial', 'PROPN', 'Financial'),
#  ('Markets', 'PROPN', 'Markets'),
#  ('     ', 'SPACE', '     '),
#  ('Business', 'PROPN', 'Business'),
#  ('Highlights', 'PROPN', 'Highlights'),
#  ('     ', 'SPACE', '     '),
#  ('Financial', 'PROPN', 'Financial'),
#  ('wellness', 'NOUN', 'wellness'),
#  ('     ', 'SPACE', '     '),
#  ('Science', 'PROPN', 'Science'),
#  ('Fact', 'PROPN', 'Fact'),
#  ('Check', 'PROPN', 'Check'),
#  ('Oddities', 'PROPN', 'Oddities'),
#  ('Newsletters', 'PROPN', 'Newsletters'),
#  ('Video', 'PROPN', 'Video'),
#  ('Health', 'PROPN', 'Health'),
#  ('Photography', 'PROPN', 'Photography'),
#  (' ', 'SPACE', ' '),
#  ('Climate', 'PROPN', 'Climate'),
#  ('Personal', 'PROPN', 'Personal'),
#  ('Finance', 'PROPN', 'Finance'),
#  ('Tech', 'PROPN', 'Tech'),
#  ('Artificial', 'PROPN', 'Artificial'),
#  ('Intelligence', 'PROPN', 'Intelligence'),
#  ('     ', 'SPACE', '     '),
#  ('Social', 'PROPN', 'Social'),
#  ('Media', 'PROPN', 'Media'),
#  ('     ', 'SPACE', '     '),
#  ('Lifestyle', 'PROPN', 'Lifestyle'),
#  ('Religion', 'PROPN', 'Religion'),
#  ('AP', 'PROPN', 'AP'),
#  ('Buyline', 'PROPN', 'Buyline'),
#  ('Personal', 'PROPN', 'Personal'),
#  ('Finance', 'PROPN', 'Finance'),
#  ('Press', 'PROPN', 'Press'),
#  ('Releases', 'PROPN', 'Releases'),
#  ('                  ', 'SPACE', '                  '),
#  ('Search', 'PROPN', 'Search'),
#  ('Query', 'PROPN', 'Query'),
#  ('               ', 'SPACE', '               '),
#  ('Submit', 'VERB', 'submit'),
#  ('Search', 'PROPN', 'Search'),
#  ('            ', 'SPACE', '            '),
#  ('Search', 'PROPN', 'Search'),
#  ('         ', 'SPACE', '         '),
#  ('World', 'PROPN', 'World'),
#  ('Israel', 'PROPN', 'Israel'),
#  ('Hamas', 'PROPN', 'Hamas'),
#  ('War', 'PROPN', 'War'),
#  ('     ', 'SPACE', '     '),
#  ('Russia', 'PROPN', 'Russia'),
#  ('Ukraine', 'PROPN', 'Ukraine'),
#  ('War', 'PROPN', 'War'),
#  ('     ', 'SPACE', '     '),
#  ('Global', 'ADJ', 'global'),
#  ('elections', 'NOUN', 'election'),
#  ('     ', 'SPACE', '     '),
#  ('Asia', 'PROPN', 'Asia'),
#  ('Pacific', 'PROPN', 'Pacific'),
#  ('     ', 'SPACE', '     '),
#  ('Latin', 'PROPN', 'Latin'),
#  ('America', 'PROPN', 'America'),
#  ('     ', 'SPACE', '     '),
#  ('Europe', 'PROPN', 'Europe'),
#  ('     ', 'SPACE', '     '),
#  ('Africa', 'PROPN', 'Africa'),
#  ('     ', 'SPACE', '     '),
#  ('Middle', 'PROPN', 'Middle'),
#  ('East', 'PROPN', 'East'),
#  ('     ', 'SPACE', '     '),
#  ('China', 'PROPN', 'China'),
#  ('     ', 'SPACE', '     '),
#  ('Australia', 'PROPN', 'Australia'),
#  ('     ', 'SPACE', '     '),
#  ('U.S.', 'PROPN', 'U.S.'),
#  ('Election', 'PROPN', 'Election'),
#  ('2024', 'NUM', '2024'),
#  ('Politics', 'PROPN', 'Politics'),
#  ('Joe', 'PROPN', 'Joe'),
#  ('Biden', 'PROPN', 'Biden'),
#  ('     ', 'SPACE', '     '),
#  ('Election', 'PROPN', 'Election'),
#  ('2024', 'NUM', '2024'),
#  ('     ', 'SPACE', '     '),
#  ('Congress', 'PROPN', 'Congress'),
#  ('     ', 'SPACE', '     '),
#  ('Sports', 'PROPN', 'Sports'),
#  ('March', 'PROPN', 'March'),
#  ('Madness', 'PROPN', 'Madness'),
#  ('     ', 'SPACE', '     '),
#  ('MLB', 'PROPN', 'MLB'),
#  ('     ', 'SPACE', '     '),
#  ('NBA', 'PROPN', 'NBA'),
#  ('     ', 'SPACE', '     '),
#  ('NHL', 'PROPN', 'NHL'),
#  ('     ', 'SPACE', '     '),
#  ('NFL', 'PROPN', 'NFL'),
#  ('     ', 'SPACE', '     '),
#  ('Soccer', 'PROPN', 'Soccer'),
#  ('     ', 'SPACE', '     '),
#  ('Golf', 'PROPN', 'Golf'),
#  ('     ', 'SPACE', '     '),
#  ('Tennis', 'PROPN', 'Tennis'),
#  ('     ', 'SPACE', '     '),
#  ('AP', 'PROPN', 'AP')]

# %% [markdown]
# ### VISUALIZE DEPENDENCY PARSING

# %%
# Render a visualization of the dependency parsing for the 4th sentence of the extracted article text with adjusted distance between words.

displacy.render(nlp(str(sentences[1])), style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="7decfc5fa1b14767a0ca06c0191b602b-0" class="displacy" width="9170" height="497.0" direction="ltr" style="max-width: none; height: 497.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Artificial</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">intelligence</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">news,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">features</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">articles</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">|</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">Live</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">Science</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">         </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">Skip</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">main</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">content</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">Open</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">menu</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">Close</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2090">menu</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2090">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">Live</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2330">Science</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2330">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">Live</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2690">Science</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2690">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2810"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2810">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2930">Search</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2930">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">  </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="3170">Search</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3170">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="3290">Live</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3290">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="3410">Science</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3410">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="3530">  </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3530">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">Subscribe</tspan>
#     <tspan class="displacy-tag" dy

# %% [markdown]
# ## 3 CONVERT URL TO TEXT AND COUNT ENTITIES

# %%
# Convert the content of a given URL into text and count the identified entities.

from bs4 import BeautifulSoup
import requests
import re
def url_to_string(url):
    res = requests.get(url)
    html = res.text
    soup = BeautifulSoup(html, 'html.parser')
    for script in soup(["script", "style", 'aside']):
        script.extract()
    return " ".join(re.split(r'[\n\t]+', soup.get_text()))
ny_bb = url_to_string('https://www.livescience.com/technology/artificial-intelligence')
article = nlp(ny_bb)
len(article.ents)
# Out:
# 100

# %% [markdown]
# ### VISUALIZE ENTITIES IN TEXT

# %%
# Render a visualization of the identified entities in the extracted article text.

displacy.render(article, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"> Artificial intelligence news, features and articles | Live Science          Skip to main content Open menu Close menu Live Science  Live Science  Search
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Search Live Science   Subscribe RSS           Space Health Planet Earth Animals Archaeology Physics &amp; Math Human Behavior Technology Chemistry More Science
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  news About Us Forum Story archive
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TrendingPrincess of Wales
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  cancerWorm MoonCanada earthquakesIceland volcanoJames
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Webb Space
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TelescopeApril 8
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  total solar eclipse
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Artificial Intelligence
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#   (Image credit: Getty Images) Artificial intelligence is here, and it's transforming every aspect of science. From
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ’s DeepMind discovering the structure of nearly every known protein to
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  deciphering a
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2,000-year-old
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  &quot;lost book,&quot; new and future computer systems that can outperform humans have near-infinite applications. discover more—Why does AI scare us so much?—4 different types of AIBut how concerned should we be with the rollout of
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
# , and what impact could this have on our world? Live Science's expert writers and editors search for answers to these questions and keep you tuned in to the wildest developments in machine learning with the latest
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  news, articles and features.     Latest about
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Artificial Intelligence  Scientists
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  create
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  models that can talk to each other and pass on skills with limited human input By
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Roland Moore-Coyler
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#   published
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     22
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     March 24
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  Scientists modeled human-like communication skills and the transfer of knowledge between AIs — so they can teach each other to perform tasks without a huge amount of training data.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Artificial Intelligence Researchers
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  gave AI an 'inner monologue' and it massively improved its performance By
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Keumars Afifi-Sabet
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#   published
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     20 March 24
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  Scientists trained an AI system to think before speaking with a technique called QuietSTaR. The inner monologue improved common sense reasoning and doubled math performance. Artificial Intelligence AI singularity may come in
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2027
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  with artificial 'super intelligence' sooner than we think, says top scientist By
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Keumars Afifi-Sabet
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0

# %% [markdown]
# ### COUNT ENTITY LABELS

# %%
# Count the occurrence of each entity label in the extracted article text.

from collections import Counter

labels = [x.label_ for x in article.ents]
Counter(labels)
# Out:
# Counter({'ORG': 26,
#          'PERSON': 16,
#          'CARDINAL': 16,
#          'DATE': 13,
#          'PRODUCT': 11,
#          'NORP': 4,
#          'TIME': 3,
#          'GPE': 3,
#          'FAC': 2,
#          'PERCENT': 2,
#          'LOC': 2,
#          'ORDINAL': 2})

# %% [markdown]
# ### COUNT MOST COMMON ENTITIES

# %%
# Count the 25 most common entities in the extracted article text.

items = [x.text for x in article.ents]
Counter(items).most_common(25)
# Out:
# [('AI', 13),
#  ('Keumars Afifi-Sabet', 7),
#  ('OpenAI', 3),
#  ('February 24', 2),
#  ('Meta', 2),
#  ('Mark Zuckerberg', 2),
#  ('19', 2),
#  ('January 24', 2),
#  ('18', 2),
#  ('Search Live Science   Subscribe RSS           Space Health Planet Earth Animals Archaeology Physics & Math Human Behavior Technology Chemistry More Science',
#   1),
#  ('TrendingPrincess of Wales', 1),
#  ('Webb Space', 1),
#  ('TelescopeApril 8', 1),
#  ('Artificial Intelligence', 1),
#  ('Google', 1),
#  ('2,000-year-old', 1),
#  ('Artificial Intelligence  Scientists', 1),
#  ('Roland Moore-Coyler', 1),
#  ('22', 1),
#  ('March 24', 1),
#  ('Artificial Intelligence Researchers', 1),
#  ('20 March 24', 1),
#  ('2027', 1),
#  ('6 March 24', 1),
#  ('three to eight years', 1)]

# %% [markdown]
# ### PRINT SPECIFIC SENTENCE

# %%
# Print the 26th sentence from the extracted article text.

sentences = [x for x in article.sents]
print(sentences[25])
# Out:
# MOST READMOST SHARED1One of our favorite Garmin watches is now half-price at Walmart — and it's an ideal running companion2Mass grave of plague victims may be largest ever found in Europe, archaeologists say3India's evolutionary past tied to huge migration 50,000 years ago and to now-extinct human relatives41,900-year-old coins from Jewish revolt against the Romans discovered in the Judaen desert5Dying SpaceX rocket creates glowing, galaxy-like spiral in the middle of the Northern Lights1'Potentially hazardous' asteroid Bennu contains the building blocks of life and minerals unseen on Earth, scientists reveal in 1st comprehensive analysis2Speck of light spotted by Hubble is one of the most enormous galaxies in the early universe, James Webb telescope reveals38-hour intermittent fasting tied to 90% higher risk of cardiovascular death, early data hint4James Webb telescope confirms there is something seriously wrong with our understanding of the universe5Beluga whales appear to change the shape of their melon heads to communicate, scientists discover Live Science is part of Future US Inc, an international media group and leading digital publisher.

# %% [markdown]
# ### VISUALIZE ENTITIES IN SPECIFIC SENTENCE

# %%
# Render a visualization of the identified entities in the 26th sentence of the extracted article text.

displacy.render(nlp(str(sentences[25])), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">MOST READMOST SHARED1One of our favorite
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Garmin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  watches is now
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     half
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# -price at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Walmart
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  — and it's an ideal running companion2Mass grave of plague victims may be largest ever found in
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Europe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , archaeologists say3India's evolutionary past tied to huge migration
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     50,000 years ago
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and to now-extinct human relatives41,900-year-old coins from
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jewish
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  revolt against the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Romans
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  discovered in the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Judaen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  desert5Dying
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SpaceX
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  rocket creates glowing, galaxy-like spiral in the middle of the Northern Lights1'Potentially hazardous' asteroid
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bennu
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  contains the building blocks of life and minerals unseen on
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Earth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , scientists reveal in
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1st
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  comprehensive analysis2Speck of light spotted by
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hubble
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  is one of the most enormous galaxies in the early universe,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     James Webb
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  telescope
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     reveals38-hour
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  intermittent fasting tied to
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     90%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  higher risk of cardiovascular death, early data hint4James
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Webb
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  telescope confirms there is something seriously wrong with our understanding of the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     universe5Beluga
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  whales appear to change the shape of their melon heads to communicate, scientists discover
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Live Science
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is part of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Future US Inc
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , an international media group and leading digital publisher.</div></span>

# %% [markdown]
# ### EXTRACT WORDS WITH PARTS OF SPEECH AND LEMMAS

# %%
# Extract words along with their parts of speech and lemmas from the 26th sentence of the extracted article text, excluding stop words and punctuation.

[(x.orth_,x.pos_, x.lemma_) for x in [y 
                                      for y
                                      in nlp(str(sentences[25])) 
                                      if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [('READMOST', 'PROPN', 'READMOST'),
#  ('SHARED1One', 'PROPN', 'SHARED1One'),
#  ('favorite', 'ADJ', 'favorite'),
#  ('Garmin', 'PROPN', 'Garmin'),
#  ('watches', 'NOUN', 'watch'),
#  ('half', 'ADJ', 'half'),
#  ('price', 'NOUN', 'price'),
#  ('Walmart', 'PROPN', 'Walmart'),
#  ('ideal', 'ADJ', 'ideal'),
#  ('running', 'VERB', 'run'),
#  ('companion2Mass', 'PROPN', 'companion2Mass'),
#  ('grave', 'NOUN', 'grave'),
#  ('plague', 'NOUN', 'plague'),
#  ('victims', 'NOUN', 'victim'),
#  ('largest', 'AUX', 'largest'),
#  ('found', 'VERB', 'find'),
#  ('Europe', 'PROPN', 'Europe'),
#  ('archaeologists', 'NOUN', 'archaeologist'),
#  ('say3India', 'PROPN', 'say3India'),
#  ('evolutionary', 'ADJ', 'evolutionary'),
#  ('past', 'NOUN', 'past'),
#  ('tied', 'VERB', 'tie'),
#  ('huge', 'ADJ', 'huge'),
#  ('migration', 'NOUN', 'migration'),
#  ('50,000', 'NUM', '50,000'),
#  ('years', 'NOUN', 'year'),
#  ('ago', 'ADV', 'ago'),
#  ('extinct', 'ADJ', 'extinct'),
#  ('human', 'ADJ', 'human'),
#  ('relatives41,900', 'PROPN', 'relatives41,900'),
#  ('year', 'NOUN', 'year'),
#  ('old', 'ADJ', 'old'),
#  ('coins', 'NOUN', 'coin'),
#  ('Jewish', 'ADJ', 'jewish'),
#  ('revolt', 'NOUN', 'revolt'),
#  ('Romans', 'PROPN', 'Romans'),
#  ('discovered', 'VERB', 'discover'),
#  ('Judaen', 'PROPN', 'Judaen'),
#  ('desert5Dying', 'PROPN', 'desert5Dying'),
#  ('SpaceX', 'PROPN', 'SpaceX'),
#  ('rocket', 'NOUN', 'rocket'),
#  ('creates', 'VERB', 'create'),
#  ('glowing', 'ADJ', 'glowing'),
#  ('galaxy', 'NOUN', 'galaxy'),
#  ('like', 'ADJ', 'like'),
#  ('spiral', 'NOUN', 'spiral'),
#  ('middle', 'NOUN', 'middle'),
#  ('Northern', 'ADJ', 'northern'),
#  ("Lights1'Potentially", 'ADV', "lights1'potentially"),
#  ('hazardous', 'ADJ', 'hazardous'),
#  ('asteroid', 'NOUN', 'asteroid'),
#  ('Bennu', 'PROPN', 'Bennu'),
#  ('contains', 'VERB', 'contain'),
#  ('building', 'NOUN', 'building'),
#  ('blocks', 'NOUN', 'block'),
#  ('life', 'NOUN', 'life'),
#  ('minerals', 'NOUN', 'mineral'),
#  ('unseen', 'ADJ', 'unseen'),
#  ('Earth', 'PROPN', 'Earth'),
#  ('scientists', 'NOUN', 'scientist'),
#  ('reveal', 'VERB', 'reveal'),
#  ('1st', 'NOUN', '1st'),
#  ('comprehensive', 'ADJ', 'comprehensive'),
#  ('analysis2Speck', 'ADV', 'analysis2speck'),
#  ('light', 'NOUN', 'light'),
#  ('spotted', 'VERB', 'spot'),
#  ('Hubble', 'PROPN', 'Hubble'),
#  ('enormous', 'ADJ', 'enormous'),
#  ('galaxies', 'NOUN', 'galaxy'),
#  ('early', 'ADJ', 'early'),
#  ('universe', 'NOUN', 'universe'),
#  ('James', 'PROPN', 'James'),
#  ('Webb', 'PROPN', 'Webb'),
#  ('telescope', 'NOUN', 'telescope'),
#  ('reveals38', 'PROPN', 'reveals38'),
#  ('hour', 'NOUN', 'hour'),
#  ('intermittent', 'ADJ', 'intermittent'),
#  ('fasting', 'NOUN', 'fasting'),
#  ('tied', 'VERB', 'tie'),
#  ('90', 'NUM', '90'),
#  ('%', 'NOUN', '%'),
#  ('higher', 'ADJ', 'high'),
#  ('risk', 'NOUN', 'risk'),
#  ('cardiovascular', 'ADJ', 'cardiovascular'),
#  ('death', 'NOUN', 'death'),
#  ('early', 'ADJ', 'early'),
#  ('data', 'NOUN', 'datum'),
#  ('hint4James', 'NOUN', 'hint4jame'),
#  ('Webb', 'PROPN', 'Webb'),
#  ('telescope', 'NOUN', 'telescope'),
#  ('confirms', 'VERB', 'confirm'),
#  ('seriously', 'ADV', 'seriously'),
#  ('wrong', 'ADJ', 'wrong'),
#  ('understanding', 'NOUN', 'understanding'),
#  ('universe5Beluga', 'ADJ', 'universe5beluga'),
#  ('whales', 'NOUN', 'whale'),
#  ('appear', 'VERB', 'appear'),
#  ('change', 'VERB', 'change'),
#  ('shape', 'NOUN', 'shape'),
#  ('melon', 'NOUN', 'melon'),
#  ('heads', 'NOUN', 'head'),
#  ('communicate', 'VERB', 'communicate'),
#  ('scientists', 'NOUN', 'scientist'),
#  ('discover', 'VERB', 'discover'),
#  ('Live', 'ADJ', 'live'),
#  ('Science', 'NOUN', 'science'),
#  ('Future', 'PROPN', 'Future'),
#  ('Inc', 'PROPN', 'Inc'),
#  ('international', 'ADJ', 'international'),
#  ('media', 'NOUN', 'medium'),
#  ('group', 'NOUN', 'group'),
#  ('leading', 'VERB', 'lead'),
#  ('digital', 'ADJ', 'digital'),
#  ('publisher', 'NOUN', 'publisher')]

# %% [markdown]
# ### VISUALIZE DEPENDENCY PARSING

# %%
# Render a visualization of the dependency parsing for the 26th sentence of the extracted article text with adjusted distance between words.

displacy.render(nlp(str(sentences[2])), style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="04b96418ef6c4ac88f64d8392dfb8354-0" class="displacy" width="1490" height="317.0" direction="ltr" style="max-width: none; height: 317.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Artificial</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">intelligence</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">here,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">it</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">'s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">transforming</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">every</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">aspect</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">science.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-04b96418ef6c4ac88f64d8392dfb8354-0-0" stroke-width="2px" d="M70,182.0 C70,122.0 160.0,122.0 160.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-04b96418ef6c4ac88f64d8392dfb8354-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,184.0 L62,172.0 78,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-04b96418ef6c4ac88f64d8392dfb8354-0-1" stroke-width="2px" d="M190,182.0 C190,122.0 280.0,122.0 280.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-04b96418ef6c4ac88f64d8392dfb8354-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M190,184.0 L182,172.0 198,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-04b96418ef6c4ac88f64d8392dfb8354-0-2" stroke-width="2px" d="M310,182.0 C310,122.0 400.0,122.0 400.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-04b96418ef6c4ac88f64d8392dfb8354-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M400.0,184.0 L408.0,172.0 392.0,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-04b96418ef6c4ac88f64d8392dfb8354-0-3" stroke-width="2px" d="M310,182.0 C310,62.0 525.0,62.0 525.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-04b96418ef6c4ac88f64d8392dfb8354-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M525.0,184.0 L533.0,172.0 517.0,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-04b96418ef6c4ac88f64d8392dfb8354-0-4" stroke-width="2px" d="M670,182.0 C670,62.0 885.0,62.0 885.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-04b96418ef6c4ac88f64d8392dfb8354-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M670,184.0 L662,172.0 678,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-04b96418ef6c4ac88f64d8392dfb8354-0-5" stroke-width="2px" d="M790,182.0 C790,122.0 880.0,122.0 880.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-04b96418ef6c4ac88f64d8392dfb8354-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M790,184.0 L782,172.0 798,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-04b96418ef6c4ac88f64d8392dfb8354-0-6" stroke-width="2px" d="M310,182.0 C310,2.0 890.0,2.0 890.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-04b96418ef6c4ac88f64d8392dfb8354-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M890.0,184.0 L898.0,172.0 882.0,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-04b96418ef6c4ac88f64d8392dfb8354-0-7" stroke-width="2px" d="M1030,182.0 C1030,122.0 1120.0,122.0 1120.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-04b96418ef6c4ac88f64d8392dfb8354-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1030,184.0 L1022,172.0 1038,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="disp
